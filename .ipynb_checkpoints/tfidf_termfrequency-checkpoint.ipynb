# %%
import math
# from future import division
from textblob import TextBlob as tb
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer


# def tf(word, blob):
#     return blob.words.count(word) / len(blob.words)

# def n_containing(word, bloblist):
#     return sum(1 for blob in bloblist if word in blob)

# def idf(word, bloblist): 
#     return math.log(len(bloblist) / (float)(1 + n_containing(word, bloblist)))

# def tfidf(word, blob, bloblist):
#     return tf(word, blob) * idf(word, bloblist)

# %%
trainData = pd.read_csv('cs230db2.PostFirstIter_dima_comments.csv',encoding = "ISO-8859-1", error_bad_lines=False)
comment0 = trainData['Comments.0'].values.tolist()
comment1 = trainData['Comments.1'].values.tolist()
comment2 = trainData['Comments.2'].values.tolist()
comment3 = trainData['Comments.3'].values.tolist()
comment4 = trainData['Comments.4'].values.tolist()
document = []
document.extend(comment0)
document.extend(comment1)
document.extend(comment2)
document.extend(comment3)
document.extend(comment4)

# %%
import string
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via']

stopWords.update(set(stopwords.words('english')))
wordnetLem = WordNetLemmatizer()
tb_document = []
#postProcessedTrainPhrases = []
for phrase in document:
    if isinstance(phrase, str):
        tokens = word_tokenize(phrase)
        parsedWords = []
        for t in tokens:
            if t not in stop:
                parsedWords.append(wordnetLem.lemmatize(t))
        tb_document.extend(parsedWords)

cleaned_document = []
for phrase in document:
    if isinstance(phrase, str):
        cleaned_document.append(phrase)

# %%
from collections import Counter
from nltk import bigrams 


terms_bigram = bigrams(tb_document)
count_all = Counter()
count_all.update(tb_document)
print(count_all.most_common(100))


# count_bigram = Counter()
# count_bigram.update(terms_bigram)
# print(count_bigram.most_common(100))
# Out:
# [('I', 35028), ("n't", 21443), ('question', 19277), ('code', 16672), ("''", 16409), ("'s", 14691), ('http', 14601), ('``', 13870), ('...', 10599), ('You', 10029), ('What', 9607), ('want', 8646), ('use', 8566), ('answer', 8254), ('need', 7264), ('problem', 6679), ('like', 6631), ('would', 6465), ('It', 6306), ('error', 6038), ('work', 5920), ('This', 5797), ('get', 5712), ('The', 5703), ('using', 5661), ('tried', 5407), ('If', 5252), ('one', 5239), ('help', 5081), ('know', 5064), ("'re", 4869), ('Please', 4331), ('file', 4153), ('make', 4058), ('see', 4022), ('function', 3994), ('post', 3970), ('value', 3960), ('mean', 3943), ('way', 3862), ('time', 3745), ('u', 3707), ('try', 3633), ('think', 3569), ('string', 3526), ("'m", 3434), ('please', 3362), ('show', 3358), ('first', 3331), ('read', 3328), ('look', 3258), ('example', 3195), ('could', 3057), ('line', 3042), ('trying', 2998), ('something', 2955), ("'ve", 2869), ('array', 2868), ('data', 2811), ('really', 2757), ('\\n', 2729), ('asking', 2722), ('method', 2696), ('Why', 2677), ('Do', 2654), ('class', 2645), ('That', 2575), ('new', 2567), ('And', 2562), ('also', 2522), ('1', 2482), ('wrong', 2468), ('give', 2386), ('even', 2384), ('number', 2333), ('good', 2327), ('understand', 2300), ('ca', 2299), ('variable', 2299), ('ask', 2261), ('thing', 2256), ('How', 2213), ('find', 2207), ('add', 2205), ('sure', 2159), ('result', 2137), ('solution', 2127), ('right', 2090), ('return', 2076), ('There', 2055), ('possible', 2050), ('user', 2028), ('say', 2027), ('instead', 2011), ('Also', 2011), ('Is', 1992), ('already', 1986), ('page', 1970), ('type', 1954), ('better', 1943)]

# %%
count_bigram = Counter()
count_bigram.update(terms_bigram)
print(count_bigram.most_common(100))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words = 'english', lowercase=True, max_df = 0.9, min_df = 2 )
tfs = tfidf.fit_transform(tb_document)
# response = tfidf.transform(tb_document)
# feature_names = tfidf.get_feature_names()
# for col in response.nonzero()[1]:
#     print(feature_names[col], ' - ', response[0, col])
indices = np.argsort(tfidf.idf_)[::-1]
features = tfidf.get_feature_names()

# %%
top_n = 1000
for i in indices[:top_n]:
    print(features[i])
    print(tfidf.idf_[i])
# top_features = [features[i] for i in indices[:top_n]]
# print(top_features)
# Out:
# kevinbowersox
# 14.015934142721564
# benim
# 14.015934142721564
# html_log
# 14.015934142721564
# prestashop
# 14.015934142721564
# html_node
# 14.015934142721564
# presentviewcontroller
# 14.015934142721564
# presents
# 14.015934142721564
# htmldocs
# 14.015934142721564
# present_tense
# 14.015934142721564
# presumes
# 14.015934142721564
# htmlelement
# 14.015934142721564
# benjaminkovach
# 14.015934142721564
# prepvars
# 14.015934142721564
# htmlgoodies
# 14.015934142721564
# preposition
# 14.015934142721564
# htmlstring
# 14.015934142721564
# presumed
# 14.015934142721564
# html5rocks
# 14.015934142721564
# bennadel
# 14.015934142721564
# believable
# 14.015934142721564
# behaved
# 14.015934142721564
# behaviors
# 14.015934142721564
# behaviour_
# 14.015934142721564
# behavour
# 14.015934142721564
# beinforce
# 14.015934142721564
# beleive
# 14.015934142721564
# believing
# 14.015934142721564
# presumptive
# 14.015934142721564
# prevalent
# 14.015934142721564
# belittling
# 14.015934142721564
# directoryinfo
# 14.015934142721564
# prettiest
# 14.015934142721564
# html2pdf
# 14.015934142721564
# presumptuous
# 14.015934142721564
# prepares
# 14.015934142721564
# benny
# 14.015934142721564
# professionnal
# 14.015934142721564
# preet
# 14.015934142721564
# http_user_agent
# 14.015934142721564
# directing
# 14.015934142721564
# bfo
# 14.015934142721564
# bfr
# 14.015934142721564
# preevent
# 14.015934142721564
# preetikasharma
# 14.015934142721564
# direct3d
# 14.015934142721564
# preferrably
# 14.015934142721564
# httplistener
# 14.015934142721564
# predicated
# 14.015934142721564
# predetermined
# 14.015934142721564
# bhashitparikh
# 14.015934142721564
# preconception
# 14.015934142721564
# httprequestcachepolicy
# 14.015934142721564
# betsworth
# 14.015934142721564
# directional
# 14.015934142721564
# bent
# 14.015934142721564
# http_access_control
# 14.015934142721564
# bereal
# 14.015934142721564
# premier
# 14.015934142721564
# htmlweb
# 14.015934142721564
# htop
# 14.015934142721564
# prelic
# 14.015934142721564
# directives
# 14.015934142721564
# bernoulli_distribution
# 14.015934142721564
# preferredheight
# 14.015934142721564
# berry
# 14.015934142721564
# bertrand
# 14.015934142721564
# prefs
# 14.015934142721564
# preformatted
# 14.015934142721564
# preform
# 14.015934142721564
# bespoke
# 14.015934142721564
# price_range_a_b
# 14.015934142721564
# hte
# 14.015934142721564
# directshow
# 14.015934142721564
# procedurally
# 14.015934142721564
# processexplorer
# 14.015934142721564
# battleship
# 14.015934142721564
# disappeard
# 14.015934142721564
# battletext
# 14.015934142721564
# baud
# 14.015934142721564
# bb387098
# 14.015934142721564
# bb549277
# 14.015934142721564
# processmessages
# 14.015934142721564
# proc_dir_entry
# 14.015934142721564
# howard
# 14.015934142721564
# probs
# 14.015934142721564
# problum
# 14.015934142721564
# probleme
# 14.015934142721564
# disambiguation
# 14.015934142721564
# processinput
# 14.015934142721564
# houssembdr
# 14.015934142721564
# primay
# 14.015934142721564
# basicobject
# 14.015934142721564
# prof83
# 14.015934142721564
# bashed
# 14.015934142721564
# products_5245_20130709_101812_2
# 14.015934142721564
# productname
# 14.015934142721564
# bashrc
# 14.015934142721564
# hourlyemp
# 14.015934142721564
# productcode
# 14.015934142721564
# house_name_2
# 14.015934142721564
# product_photo
# 14.015934142721564
# basile
# 14.015934142721564
# product_description
# 14.015934142721564
# house_name_1
# 14.015934142721564
# proclaimed
# 14.015934142721564
# procfile
# 14.015934142721564
# probing
# 14.015934142721564
# proberly
# 14.015934142721564
# probem
# 14.015934142721564
# print_r_reverse
# 14.015934142721564
# printscreen
# 14.015934142721564
# printlist
# 14.015934142721564
# beeper
# 14.015934142721564
# beetroot
# 14.015934142721564
# printbooks
# 14.015934142721564
# beforerender
# 14.015934142721564
# principe
# 14.015934142721564
# probe
# 14.015934142721564
# hsaur
# 14.015934142721564
# prince
# 14.015934142721564
# primitives
# 14.015934142721564
# hsqldb
# 14.015934142721564
# hssf
# 14.015934142721564
# ht
# 14.015934142721564
# printsum
# 14.015934142721564
# printvalid
# 14.015934142721564
# printwriter
# 14.015934142721564
# becoz
# 14.015934142721564
# disallowed
# 14.015934142721564
# hpa
# 14.015934142721564
# prism
# 14.015934142721564
# pristine
# 14.015934142721564
# disambiguate
# 14.015934142721564
# privately
# 14.015934142721564
# privileged
# 14.015934142721564
# howtos
# 14.015934142721564
# disambiguated
# 14.015934142721564
# prizelabel
# 14.015934142721564
# prng
# 14.015934142721564
# be1
# 14.015934142721564
# bdesham
# 14.015934142721564
# precomposed
# 14.015934142721564
# httprequestmessage
# 14.015934142721564
# bhavin
# 14.015934142721564
# popupdiv
# 14.015934142721564
# bits_long
# 14.015934142721564
# bitset
# 14.015934142721564
# bitshift
# 14.015934142721564
# hyphens
# 14.015934142721564
# hypothetically
# 14.015934142721564
# bitshifts
# 14.015934142721564
# popup_bg
# 14.015934142721564
# hyperic
# 14.015934142721564
# bitsize
# 14.015934142721564
# popunder
# 14.015934142721564
# bitter
# 14.015934142721564
# bitwise_operations_in_c
# 14.015934142721564
# i1081534
# 14.015934142721564
# dilshod
# 14.015934142721564
# diminish
# 14.015934142721564
# portfolio
# 14.015934142721564
# birdwatching
# 14.015934142721564
# hwhattohack
# 14.015934142721564
# birt
# 14.015934142721564
# positions
# 14.015934142721564
# birthdate
# 14.015934142721564
# dinamically
# 14.015934142721564
# positionabsolute
# 14.015934142721564
# bitmapfactory
# 14.015934142721564
# posible
# 14.015934142721564
# hyperbole
# 14.015934142721564
# dimitrov
# 14.015934142721564
# hx
# 14.015934142721564
# portlet
# 14.015934142721564
# portlandrunner
# 14.015934142721564
# portland
# 14.015934142721564
# bitop
# 14.015934142721564
# bkn005
# 14.015934142721564
# popsize
# 14.015934142721564
# i386
# 14.015934142721564
# blazart
# 14.015934142721564
# digit_seen
# 14.015934142721564
# polluted
# 14.015934142721564
# digged
# 14.015934142721564
# iboutlets
# 14.015934142721564
# political
# 14.015934142721564
# ic
# 14.015934142721564
# icbytes
# 14.015934142721564
# i4
# 14.015934142721564
# blazejczapp
# 14.015934142721564
# policies
# 14.015934142721564
# police
# 14.015934142721564
# pokey
# 14.015934142721564
# icepack
# 14.015934142721564
# pojos
# 14.015934142721564
# poly
# 14.015934142721564
# polyfill
# 14.015934142721564
# ianpgall
# 14.015934142721564
# polynomially
# 14.015934142721564
# digitalpoint
# 14.015934142721564
# ponder
# 14.015934142721564
# dilemma
# 14.015934142721564
# iad
# 14.015934142721564
# blagovestbuyukliev
# 14.015934142721564
# poop
# 14.015934142721564
# blackvegetable
# 14.015934142721564
# poorest
# 14.015934142721564
# pop2
# 14.015934142721564
# i_terminal_id
# 14.015934142721564
# i7
# 14.015934142721564
# dilems
# 14.015934142721564
# popfalushi
# 14.015934142721564
# positives
# 14.015934142721564
# posofdot
# 14.015934142721564
# bheshgurung
# 14.015934142721564
# practiced
# 14.015934142721564
# bidi
# 14.015934142721564
# pradeepa
# 14.015934142721564
# pradeep
# 14.015934142721564
# big5
# 14.015934142721564
# dipeshparmar
# 14.015934142721564
# bigcommerce
# 14.015934142721564
# bigdata
# 14.015934142721564
# huangism
# 14.015934142721564
# hugely
# 14.015934142721564
# bigmike
# 14.015934142721564
# pr11
# 14.015934142721564
# pprice3
# 14.015934142721564
# bignerdranch
# 14.015934142721564
# ppm
# 14.015934142721564
# diplay
# 14.015934142721564
# pragmatic
# 14.015934142721564
# posofi
# 14.015934142721564
# prash
# 14.015934142721564
# httprequests
# 14.015934142721564
# precedent
# 14.015934142721564
# bicubic
# 14.015934142721564
# dir2
# 14.015934142721564
# httpsurlconnection
# 14.015934142721564
# httputility
# 14.015934142721564
# prasadkharkar
# 14.015934142721564
# pragmatically
# 14.015934142721564
# pranayrana
# 14.015934142721564
# pranav
# 14.015934142721564
# praks411
# 14.015934142721564
# pragnani
# 14.015934142721564
# pragmatism
# 14.015934142721564
# pragmatictips
# 14.015934142721564
# bignum
# 14.015934142721564
# hugo
# 14.015934142721564
# ppe
# 14.015934142721564
# binomial
# 14.015934142721564
# bindinglist
# 14.015934142721564
# postget
# 14.015934142721564
# binged
# 14.015934142721564
# dinesh
# 14.015934142721564
# postdelayed
# 14.015934142721564
# postcode_1
# 14.015934142721564
# binprog
# 14.015934142721564
# dipesh
# 14.015934142721564
# postaldb
# 14.015934142721564
# post_content
# 14.015934142721564
# binyaminsharet
# 14.015934142721564
# possiblity
# 14.015934142721564
# birds
# 14.015934142721564
# possessive
# 14.015934142721564
# huntermcmillen
# 14.015934142721564
# binderdata
# 14.015934142721564
# postmessage
# 14.015934142721564
# postulate
# 14.015934142721564
# pot
# 14.015934142721564
# hunch
# 14.015934142721564
# potatoswatter
# 14.015934142721564
# humptydumpty
# 14.015934142721564
# potion
# 14.015934142721564
# billz
# 14.015934142721564
# humour
# 14.015934142721564
# billy
# 14.015934142721564
# humanresources
# 14.015934142721564
# bilinear
# 14.015934142721564
# powerx
# 14.015934142721564
# hulk007
# 14.015934142721564
# pp1
# 14.015934142721564
# professionally
# 14.015934142721564
# baseless
# 14.015934142721564
# blazingly
# 14.015934142721564
# hits
# 14.015934142721564
# avalue_1
# 14.015934142721564
# avalue_2
# 14.015934142721564
# qtylist
# 14.015934142721564
# displays
# 14.015934142721564
# hit_points
# 14.015934142721564
# hithere
# 14.015934142721564
# qtcreator
# 14.015934142721564
# avalue_0
# 14.015934142721564
# qt5
# 14.015934142721564
# averse
# 14.015934142721564
# qpushbutton
# 14.015934142721564
# qoop
# 14.015934142721564
# hjpotter92
# 14.015934142721564
# qiau
# 14.015934142721564
# qualification
# 14.015934142721564
# available_credit
# 14.015934142721564
# qdtoshpneiyuw17queyx
# 14.015934142721564
# quantitative
# 14.015934142721564
# autopostback
# 14.015934142721564
# hipster
# 14.015934142721564
# hiralbhimani
# 14.015934142721564
# quasi
# 14.015934142721564
# autorunning
# 14.015934142721564
# disposition
# 14.015934142721564
# hires
# 14.015934142721564
# dispnam
# 14.015934142721564
# quantifiers
# 14.015934142721564
# qualitycatalyst
# 14.015934142721564
# availabe
# 14.015934142721564
# qualitative
# 14.015934142721564
# qualifying
# 14.015934142721564
# hiroto
# 14.015934142721564
# aversion
# 14.015934142721564
# qcombobox
# 14.015934142721564
# profile1
# 14.015934142721564
# hn
# 14.015934142721564
# pydan
# 14.015934142721564
# displayday
# 14.015934142721564
# py2exe
# 14.015934142721564
# pxl
# 14.015934142721564
# awnser
# 14.015934142721564
# pws
# 14.015934142721564
# pw1
# 14.015934142721564
# pyflakes
# 14.015934142721564
# pvcurrcd
# 14.015934142721564
# displayanswers
# 14.015934142721564
# hoe
# 14.015934142721564
# hog
# 14.015934142721564
# axis2
# 14.015934142721564
# putchar
# 14.015934142721564
# pydata
# 14.015934142721564
# pyfunc
# 14.015934142721564
# averybigstring
# 14.015934142721564
# pythonhosted
# 14.015934142721564
# q3
# 14.015934142721564
# q2
# 14.015934142721564
# hk
# 14.015934142721564
# q0gwd
# 14.015934142721564
# pyxx
# 14.015934142721564
# hkpeprah
# 14.015934142721564
# avi
# 14.015934142721564
# awashburn
# 14.015934142721564
# displaymonth
# 14.015934142721564
# pythagoras
# 14.015934142721564
# awake
# 14.015934142721564
# pypy
# 14.015934142721564
# pypdf
# 14.015934142721564
# pyglet
# 14.015934142721564
# query3
# 14.015934142721564
# query_link1
# 14.015934142721564
# query_posts
# 14.015934142721564
# quuestion
# 14.015934142721564
# authenticator
# 14.015934142721564
# r_inferno
# 14.015934142721564
# authoring
# 14.015934142721564
# r08
# 14.015934142721564
# qwt
# 14.015934142721564
# qwidget
# 14.015934142721564
# qusetion
# 14.015934142721564
# rabqavsystem
# 14.015934142721564
# hideously
# 14.015934142721564
# distracted
# 14.015934142721564
# authorname
# 14.015934142721564
# distmap
# 14.015934142721564
# quot
# 14.015934142721564
# quo
# 14.015934142721564
# hibernatetemplate
# 14.015934142721564
# racernerd
# 14.015934142721564
# queryable
# 14.015934142721564
# radiogroup
# 14.015934142721564
# rage
# 14.015934142721564
# raeki
# 14.015934142721564
# raedwald
# 14.015934142721564
# rae1n
# 14.015934142721564
# hhh
# 14.015934142721564
# aus
# 14.015934142721564
# hhmmss
# 14.015934142721564
# rachel
# 14.015934142721564
# disturbing
# 14.015934142721564
# auselen
# 14.015934142721564
# radically
# 14.015934142721564
# radialgradientbrush
# 14.015934142721564
# radial
# 14.015934142721564
# racking
# 14.015934142721564
# quiz10
# 14.015934142721564
# autoboxed
# 14.015934142721564
# highcharts
# 14.015934142721564
# automaticaly
# 14.015934142721564
# hii
# 14.015934142721564
# autoloading
# 14.015934142721564
# hijacked
# 14.015934142721564
# questioin
# 14.015934142721564
# questio
# 14.015934142721564
# questin
# 14.015934142721564
# hijacking
# 14.015934142721564
# quitted
# 14.015934142721564
# disqualify
# 14.015934142721564
# hilarity
# 14.015934142721564
# queryselector
# 14.015934142721564
# queryrun
# 14.015934142721564
# hilighting
# 14.015934142721564
# queryhere
# 14.015934142721564
# hightforrowatindexpath
# 14.015934142721564
# autolink
# 14.015934142721564
# questionnaire
# 14.015934142721564
# questions_
# 14.015934142721564
# quetzalcoatl
# 14.015934142721564
# autohotkey
# 14.015934142721564
# queueing
# 14.015934142721564
# queues
# 14.015934142721564
# quibble
# 14.015934142721564
# autogenerated
# 14.015934142721564
# autogeneratecolumns
# 14.015934142721564
# dissabling
# 14.015934142721564
# autocompleting
# 14.015934142721564
# autocompletetextview
# 14.015934142721564
# quines
# 14.015934142721564
# distill
# 14.015934142721564
# distinctly
# 14.015934142721564
# aye
# 14.015934142721564
# aynway
# 14.015934142721564
# ayyappansekar
# 14.015934142721564
# barathbushan
# 14.015934142721564
# proofing
# 14.015934142721564
# horn
# 14.015934142721564
# discreet
# 14.015934142721564
# banking
# 14.015934142721564
# bans
# 14.015934142721564
# promised
# 14.015934142721564
# barbara
# 14.015934142721564
# discription
# 14.015934142721564
# projs
# 14.015934142721564
# projecttype
# 14.015934142721564
# horrifically
# 14.015934142721564
# projecting
# 14.015934142721564
# project2
# 14.015934142721564
# hoster
# 14.015934142721564
# banding
# 14.015934142721564
# propblem
# 14.015934142721564
# baked
# 14.015934142721564
# hopelessly
# 14.015934142721564
# prosper
# 14.015934142721564
# bakudan
# 14.015934142721564
# disgrace
# 14.015934142721564
# proposes
# 14.015934142721564
# disfunctional
# 14.015934142721564
# balise
# 14.015934142721564
# proportionally
# 14.015934142721564
# band
# 14.015934142721564
# proportional
# 14.015934142721564
# balloon
# 14.015934142721564
# propertyname
# 14.015934142721564
# balsamiq
# 14.015934142721564
# bam
# 14.015934142721564
# propercase
# 14.015934142721564
# barest
# 14.015934142721564
# proj
# 14.015934142721564
# proid
# 14.015934142721564
# base64inputstream
# 14.015934142721564
# programaticaly
# 14.015934142721564
# base36
# 14.015934142721564
# program2
# 14.015934142721564
# base64_decode
# 14.015934142721564
# progid
# 14.015934142721564
# discern
# 14.015934142721564
# profound
# 14.015934142721564
# prohibited
# 14.015934142721564
# baseadapter
# 14.015934142721564
# profiles
# 14.015934142721564
# basebc
# 14.015934142721564
# disc
# 14.015934142721564
# hotlinking
# 14.015934142721564
# profile_id
# 14.015934142721564
# programdata
# 14.015934142721564
# hostnameverifier
# 14.015934142721564
# programers
# 14.015934142721564
# barton
# 14.015934142721564
# bartkiers
# 14.015934142721564
# bartfriederichs
# 14.015934142721564
# bartekbanachewicz
# 14.015934142721564
# bars
# 14.015934142721564
# barnabasszabolcs
# 14.015934142721564
# programming_
# 14.015934142721564
# programmingsimplified
# 14.015934142721564
# programmingwithobjectivec
# 14.015934142721564
# programname
# 14.015934142721564
# programsdir
# 14.015934142721564
# discontinued
# 14.015934142721564
# proguard
# 14.015934142721564
# hostgator
# 14.015934142721564
# baker
# 14.015934142721564
# honoring
# 14.015934142721564
# hokey
# 14.015934142721564
# b_data
# 14.015934142721564
# b7
# 14.015934142721564
# pukiwiki
# 14.015934142721564
# b8
# 14.015934142721564
# b9
# 14.015934142721564
# publishes
# 14.015934142721564
# publish_date
# 14.015934142721564
# b_list
# 14.015934142721564
# b4a
# 14.015934142721564
# publications
# 14.015934142721564
# b_name
# 14.015934142721564
# publically
# 14.015934142721564
# b_ö_____ü
# 14.015934142721564
# holterman
# 14.015934142721564
# ptrfunc
# 14.015934142721564
# b64decode
# 14.015934142721564
# b3
# 14.015934142721564
# honeycomb
# 14.015934142721564
# dispatchertimer
# 14.015934142721564
# purse
# 14.015934142721564
# purposely
# 14.015934142721564
# purposed
# 14.015934142721564
# purge
# 14.015934142721564
# aziz
# 14.015934142721564
# purdue
# 14.015934142721564
# purchased
# 14.015934142721564
# punctuated
# 14.015934142721564
# dispatched
# 14.015934142721564
# puppet
# 14.015934142721564
# pupil
# 14.015934142721564
# punker76
# 14.015934142721564
# holderid
# 14.015934142721564
# b2ato
# 14.015934142721564
# baadshah
# 14.015934142721564
# dismissal
# 14.015934142721564
# pthread_join
# 14.015934142721564
# badges
# 14.015934142721564
# backround
# 14.015934142721564
# homepage2
# 14.015934142721564
# homescreen
# 14.015934142721564
# hometoast
# 14.015934142721564
# disliked
# 14.015934142721564
# homeworkoverflow
# 14.015934142721564
# prova
# 14.015934142721564
# home3
# 14.015934142721564
# prototypical
# 14.015934142721564
# prototypes
# 14.015934142721564
# disjoint
# 14.015934142721564
# disheartened
# 14.015934142721564
# honey
# 14.015934142721564
# protomember
# 14.015934142721564
# provokes
# 14.015934142721564
# disliking
# 14.015934142721564
# prpgferret
# 14.015934142721564
# prvt1
# 14.015934142721564
# backgroung
# 14.015934142721564
# backgroundworker1
# 14.015934142721564
# background_02
# 14.015934142721564
# pshemo
# 14.015934142721564
# pshl9dcsiuw
# 14.015934142721564
# backgammon
# 14.015934142721564
# pstree
# 14.015934142721564
# psu
# 14.015934142721564
# homebrew
# 14.015934142721564
# dismal
# 14.015934142721564
# homeactivity
# 14.015934142721564
# backbtn
# 14.015934142721564
# babakfaghihian
# 14.015934142721564
# digestible
# 14.015934142721564
# blckknght
# 14.015934142721564
# setspan
# 14.015934142721564
# btrfs
# 14.015934142721564
# parseboolean
# 14.015934142721564
# parse_file
# 14.015934142721564
# impenetrable
# 14.015934142721564
# parking
# 14.015934142721564
# pareshmayani
# 14.015934142721564
# imperfect
# 14.015934142721564
# impersonation
# 14.015934142721564
# btng
# 14.015934142721564
# impetus
# 14.015934142721564
# btwn
# 14.015934142721564
# btype
# 14.015934142721564
# devolus
# 14.015934142721564
# bubblecolor
# 14.015934142721564
# implementation_
# 14.015934142721564
# parsedate
# 14.015934142721564
# btnclose
# 14.015934142721564
# paranoia
# 14.015934142721564
# bryanchen
# 14.015934142721564
# immature
# 14.015934142721564
# partly
# 14.015934142721564
# partitions
# 14.015934142721564
# dfa
# 14.015934142721564
# partite
# 14.015934142721564
# immediatly
# 14.015934142721564
# imminently
# 14.015934142721564
# btn1
# 14.015934142721564
# bryanoakley
# 14.015934142721564
# bsd
# 14.015934142721564
# bsearch
# 14.015934142721564
# part1
# 14.015934142721564
# bssid
# 14.015934142721564
# parsers
# 14.015934142721564
# paranthesis
# 14.015934142721564
# devide
# 14.015934142721564
# imagescrollview
# 14.015934142721564
# importdata
# 14.015934142721564
# paolo
# 14.015934142721564
# panpa
# 14.015934142721564
# pangea
# 14.015934142721564
# panel1
# 14.015934142721564
# buffsize
# 14.015934142721564
# bugged
# 14.015934142721564
# builtins
# 14.015934142721564
# devel
# 14.015934142721564
# pan
# 14.015934142721564
# bulb
# 14.015934142721564
# palladium
# 14.015934142721564
# buljan
# 14.015934142721564
# paletlyicon
# 14.015934142721564
# palce
# 14.015934142721564
# paperclip
# 14.015934142721564
# pappa
# 14.015934142721564
# parametric
# 14.015934142721564
# budgetpivot
# 14.015934142721564
# bucket_sort
# 14.015934142721564
# deviating
# 14.015934142721564
# parameterizing
# 14.015934142721564
# implment
# 14.015934142721564
# parameterize
# 14.015934142721564
# devguide
# 14.015934142721564
# parallely
# 14.015934142721564
# bufferedimage
# 14.015934142721564
# parallelize
# 14.015934142721564
# parallelising
# 14.015934142721564
# buettner
# 14.015934142721564
# impolite
# 14.015934142721564
# paradox
# 14.015934142721564
# parade
# 14.015934142721564
# imitate
# 14.015934142721564
# brushes
# 14.015934142721564
# party_indices
# 14.015934142721564
# patter
# 14.015934142721564
# paulhiemstra
# 14.015934142721564
# paulbellora
# 14.015934142721564
# paulbain
# 14.015934142721564
# bridging
# 14.015934142721564
# pattyd
# 14.015934142721564
# brightness
# 14.015934142721564
# briosheje
# 14.015934142721564
# brianagnew
# 14.015934142721564
# patricia_shanahan
# 14.015934142721564
# patindex
# 14.015934142721564
# patientid
# 14.015934142721564
# britain
# 14.015934142721564
# imagined
# 14.015934142721564
# paticular
# 14.015934142721564
# paulvargas
# 14.015934142721564
# pavelanossov
# 14.015934142721564
# brushed
# 14.015934142721564
# brendanlong
# 14.015934142721564
# breathe
# 14.015934142721564
# pborreli
# 14.015934142721564
# pblock
# 14.015934142721564
# pb2q
# 14.015934142721564
# brenbarn
# 14.015934142721564
# payments
# 14.015934142721564
# bres
# 14.015934142721564
# pavelkatunin
# 14.015934142721564
# dgi
# 14.015934142721564
# payflow
# 14.015934142721564
# paycheck
# 14.015934142721564
# payamhesami
# 14.015934142721564
# imagick
# 14.015934142721564
# pavlo
# 14.015934142721564
# imammal
# 14.015934142721564
# broadcastbrick
# 14.015934142721564
# pathfinding
# 14.015934142721564
# imgobj
# 14.015934142721564
# password2
# 14.015934142721564
# brth
# 14.015934142721564
# imgareaselect
# 14.015934142721564
# passw
# 14.015934142721564
# passphrase
# 14.015934142721564
# imghp
# 14.015934142721564
# bruh
# 14.015934142721564
# imbert
# 14.015934142721564
# passant
# 14.015934142721564
# passage
# 14.015934142721564
# bruno
# 14.015934142721564
# pascaleabouabdo
# 14.015934142721564
# brush1
# 14.015934142721564
# pas1
# 14.015934142721564
# password_compare
# 14.015934142721564
# img_column
# 14.015934142721564
# passwordchar
# 14.015934142721564
# browxy
# 14.015934142721564
# browsersniffing
# 14.015934142721564
# pastbin
# 14.015934142721564
# browser_
# 14.015934142721564
# paste2
# 14.015934142721564
# brown
# 14.015934142721564
# broker
# 14.015934142721564
# img3
# 14.015934142721564
# dfsq
# 14.015934142721564
# patched
# 14.015934142721564
# imformation
# 14.015934142721564
# imei
# 14.015934142721564
# broadcastreceiver
# 14.015934142721564
# path_
# 14.015934142721564
# palatable
# 14.015934142721564
# pairwise
# 14.015934142721564
# bulk_create
# 14.015934142721564
# despise
# 14.015934142721564
# outsource
# 14.015934142721564
# c01_2
# 14.015934142721564
# c07
# 14.015934142721564
# outrageous
# 14.015934142721564
# c1083
# 14.015934142721564
# inbuild
# 14.015934142721564
# incapable
# 14.015934142721564
# outstanding
# 14.015934142721564
# output_file
# 14.015934142721564
# output_1
# 14.015934142721564
# outofrange
# 14.015934142721564
# c2512
# 14.015934142721564
# outlive
# 14.015934142721564
# incident
# 14.015934142721564
# c0000005
# 14.015934142721564
# destroy_all
# 14.015934142721564
# overlong
# 14.015934142721564
# inane
# 14.015934142721564
# buzzword
# 14.015934142721564
# destruction
# 14.015934142721564
# overlays
# 14.015934142721564
# bwoebi
# 14.015934142721564
# inadvertently
# 14.015934142721564
# inafziger
# 14.015934142721564
# overcomplicating
# 14.015934142721564
# outweighs
# 14.015934142721564
# overcomplicate
# 14.015934142721564
# overcommit
# 14.015934142721564
# overapi
# 14.015934142721564
# inattention
# 14.015934142721564
# oven
# 14.015934142721564
# inb4
# 14.015934142721564
# outlaw
# 14.015934142721564
# c5
# 14.015934142721564
# include_guard
# 14.015934142721564
# cairo
# 14.015934142721564
# ost
# 14.015934142721564
# deserializes
# 14.015934142721564
# osgi
# 14.015934142721564
# oscar
# 14.015934142721564
# cagr
# 14.015934142721564
# orthos
# 14.015934142721564
# orrj0
# 14.015934142721564
# c_002b_002b
# 14.015934142721564
# orpheus
# 14.015934142721564
# incognito
# 14.015934142721564
# cakedc
# 14.015934142721564
# orignumber
# 14.015934142721564
# originaltape
# 14.015934142721564
# cakestrap
# 14.015934142721564
# osversion
# 14.015934142721564
# cafe
# 14.015934142721564
# osxhiguidelines
# 14.015934142721564
# otheres
# 14.015934142721564
# designation
# 14.015934142721564
# otherstuff
# 14.015934142721564
# designers
# 14.015934142721564
# ots
# 14.015934142721564
# ou
# 14.015934142721564
# include_path
# 14.015934142721564
# cabbage
# 14.015934142721564
# ouh
# 14.015934142721564
# ounce
# 14.015934142721564
# oups
# 14.015934142721564
# designshack
# 14.015934142721564
# ouputs
# 14.015934142721564
# outburst
# 14.015934142721564
# buzz
# 14.015934142721564
# overlook
# 14.015934142721564
# devangrathod
# 14.015934142721564
# pacman
# 14.015934142721564
# detective
# 14.015934142721564
# improbable
# 14.015934142721564
# pag
# 14.015934142721564
# bunit
# 14.015934142721564
# pad_index
# 14.015934142721564
# bur
# 14.015934142721564
# burhan
# 14.015934142721564
# page_
# 14.015934142721564
# packer
# 14.015934142721564
# packed
# 14.015934142721564
# impromptu
# 14.015934142721564
# packagemanager
# 14.015934142721564
# packaged
# 14.015934142721564
# burkhard
# 14.015934142721564
# page3
# 14.015934142721564
# page_background_color
# 14.015934142721564
# buyingdo
# 14.015934142721564
# imposed
# 14.015934142721564
# bulletproof
# 14.015934142721564
# bullied
# 14.015934142721564
# painless
# 14.015934142721564
# bumbleb2na
# 14.015934142721564
# deterrent
# 14.015934142721564
# bumpx
# 14.015934142721564
# pagey
# 14.015934142721564
# page_content
# 14.015934142721564
# pagex
# 14.015934142721564
# pagesize
# 14.015934142721564
# impossibility
# 14.015934142721564
# pagenumber
# 14.015934142721564
# determination
# 14.015934142721564
# pageinit
# 14.015934142721564
# pablo1977
# 14.015934142721564
# pa300
# 14.015934142721564
# p_userdata
# 14.015934142721564
# overthinking
# 14.015934142721564
# bust
# 14.015934142721564
# ovid
# 14.015934142721564
# butchered
# 14.015934142721564
# butnotthis
# 14.015934142721564
# imsop
# 14.015934142721564
# butt
# 14.015934142721564
# oversimplify
# 14.015934142721564
# p_time
# 14.015934142721564
# det
# 14.015934142721564
# buttom
# 14.015934142721564
# overridemimetype
# 14.015934142721564
# destructure
# 14.015934142721564
# button6
# 14.015934142721564
# overlooking
# 14.015934142721564
# ims
# 14.015934142721564
# bussiness
# 14.015934142721564
# businessaccount
# 14.015934142721564
# imput
# 14.015934142721564
# owwr2
# 14.015934142721564
# oxford
# 14.015934142721564
# p0730
# 14.015934142721564
# p0rter
# 14.015934142721564
# p0w
# 14.015934142721564
# p12
# 14.015934142721564
# burns
# 14.015934142721564
# p20d
# 14.015934142721564
# p2x
# 14.015934142721564
# p385
# 14.015934142721564
# detailsview
# 14.015934142721564
# p4
# 14.015934142721564
# detailtextdate
# 14.015934142721564
# dgibbs
# 14.015934142721564
# pcb138
# 14.015934142721564
# pointer_return
# 14.015934142721564
# pirating
# 14.015934142721564
# bobson
# 14.015934142721564
# pitt
# 14.015934142721564
# differentiates
# 14.015934142721564
# pistacchio
# 14.015934142721564
# pissed
# 14.015934142721564
# identifierforvendor
# 14.015934142721564
# pirate
# 14.015934142721564
# pixelchemist
# 14.015934142721564
# pipui
# 14.015934142721564
# pippin1289
# 14.015934142721564
# piping
# 14.015934142721564
# pipermail
# 14.015934142721564
# bobthyasian
# 14.015934142721564
# bode
# 14.015934142721564
# bobhorn
# 14.015934142721564
# pixref
# 14.015934142721564
# piou
# 14.015934142721564
# place1
# 14.015934142721564
# bmi
# 14.015934142721564
# bmk
# 14.015934142721564
# bmorris591
# 14.015934142721564
# bmrdetaildatadiv
# 14.015934142721564
# place3
# 14.015934142721564
# place2
# 14.015934142721564
# boast
# 14.015934142721564
# bobblogge
# 14.015934142721564
# pkheadercontrol
# 14.015934142721564
# identifiable
# 14.015934142721564
# boat
# 14.015934142721564
# pjgyu
# 14.015934142721564
# pizzaprice
# 14.015934142721564
# pizzaname
# 14.015934142721564
# bodycontent
# 14.015934142721564
# piokuc
# 14.015934142721564
# dgomez
# 14.015934142721564
# didint
# 14.015934142721564
# didreceiveremotenotification
# 14.015934142721564
# bombard
# 14.015934142721564
# boncodigo
# 14.015934142721564
# idno
# 14.015934142721564
# pickafile
# 14.015934142721564
# picasso
# 14.015934142721564
# picard
# 14.015934142721564
# idiotic
# 14.015934142721564
# bonkers
# 14.015934142721564
# idtextbox
# 14.015934142721564
# bonobo
# 14.015934142721564
# phusion
# 14.015934142721564
# phtime
# 14.015934142721564
# bookcasey
# 14.015934142721564
# pickupitemwithrobot
# 14.015934142721564
# pics
# 14.015934142721564
# differencing
# 14.015934142721564
# boiled
# 14.015934142721564
# differed
# 14.015934142721564
# bogosort
# 14.015934142721564
# pine
# 14.015934142721564
# pinc
# 14.015934142721564
# diffcult
# 14.015934142721564
# pileborg
# 14.015934142721564
# pieters
# 14.015934142721564
# picture_count
# 14.015934142721564
# piecharts
# 14.015934142721564
# bojanskrchevski
# 14.015934142721564
# boldpattern
# 14.015934142721564
# didselectrowforindexpath
# 14.015934142721564
# picturepopup
# 14.015934142721564
# idioms
# 14.015934142721564
# plagiarize
# 14.015934142721564
# plague
# 14.015934142721564
# plagued
# 14.015934142721564
# plumbing
# 14.015934142721564
# plzz
# 14.015934142721564
# blitting
# 14.015934142721564
# diffs
# 14.015934142721564
# plusgoogle
# 14.015934142721564
# diffrences
# 14.015934142721564
# id3
# 14.015934142721564
# plugin_api
# 14.015934142721564
# pm100
# 14.015934142721564
# id_cmt
# 14.015934142721564
# plsql
# 14.015934142721564
# blocker
# 14.015934142721564
# plottimeseries
# 14.015934142721564
# id_event
# 14.015934142721564
# plop
# 14.015934142721564
# blinked
# 14.015934142721564
# pn
# 14.015934142721564
# bm
# 14.015934142721564
# pogos
# 14.015934142721564
# bleeding
# 14.015934142721564
# pointedears
# 14.015934142721564
# blend
# 14.015934142721564
# pointcut
# 14.015934142721564
# blended
# 14.015934142721564
# blending
# 14.015934142721564
# poem
# 14.015934142721564
# blinded
# 14.015934142721564
# icomparable
# 14.015934142721564
# icomparer
# 14.015934142721564
# dificult
# 14.015934142721564
# poc
# 14.015934142721564
# icons
# 14.015934142721564
# iconv
# 14.015934142721564
# id_ingredients
# 14.015934142721564
# ploegnaam
# 14.015934142721564
# plnkr
# 14.015934142721564
# playback
# 14.015934142721564
# playerid
# 14.015934142721564
# playerhand2
# 14.015934142721564
# playerhand
# 14.015934142721564
# playedat
# 14.015934142721564
# playdatatoend
# 14.015934142721564
# playcool
# 14.015934142721564
# playable
# 14.015934142721564
# plists
# 14.015934142721564
# platter
# 14.015934142721564
# differnet
# 14.015934142721564
# ideea
# 14.015934142721564
# planmonth
# 14.015934142721564
# ident_current
# 14.015934142721564
# bluntly
# 14.015934142721564
# playerloc
# 14.015934142721564
# differrent
# 14.015934142721564
# playfair
# 14.015934142721564
# bloomsize
# 14.015934142721564
# idbiodata
# 14.015934142721564
# playlisttrack
# 14.015934142721564
# playnow
# 14.015934142721564
# playradio
# 14.015934142721564
# idavid
# 14.015934142721564
# idan
# 14.015934142721564
# pleae
# 14.015934142721564
# pleasant
# 14.015934142721564
# id_user
# 14.015934142721564
# pleaseeeeeeee
# 14.015934142721564
# bloggers
# 14.015934142721564
# blocksize
# 14.015934142721564
# id_of_element
# 14.015934142721564
# idx_
# 14.015934142721564
# phpvariable
# 14.015934142721564
# ie5
# 14.015934142721564
# percentile
# 14.015934142721564

# %%
from nltk import bigrams 
 
terms_bigram = bigrams(terms_stop)
