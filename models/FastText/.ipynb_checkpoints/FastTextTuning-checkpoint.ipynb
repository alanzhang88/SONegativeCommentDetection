# %%
import matplotlib.pyplot as plt
import seaborn as sns
import json
import numpy as np
import matplotlib.patches as mpatches
from IPython.display import HTML, display
import tabulate
import pandas as pd

# %%
def create_classifier(train_file, model_name, epoch, lr, ngrams, loss, dim, ws):
    return fasttext.supervised(train_file,
                               model_name,
                               epoch=epoch,
                               dim=dim,
                               word_ngrams=ngrams,
                               lr=lr,
                               ws=ws,
                               min_count=5,
                               bucket=2000000,
                               loss=loss)

# %%
import fasttext
from FastText import FastText
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
# Out:
# init
# Loading and preprocessing data...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6f61ec740496> in <module>()
#       1 import fasttext
# ----> 2 from FastText import FastText
#       3 from sklearn.metrics import confusion_matrix
#       4 from sklearn.metrics import precision_recall_fscore_support
#
# ~/Documents/SONegativeCommentDetection/Models/FastText/FastText.py in <module>()
#     220 isDS = False
#     221 instance = FastText()
# --> 222 instance.classify(file,isDS)
#     223
#     224
#
# ~/Documents/SONegativeCommentDetection/Models/FastText/FastText.py in classify(self, file, isDS)
#     150     def classify(self, file, isDS):
#     151         # preprocess data
# --> 152         (postProcessedTrainPhrases, postProcessedTestPhrases, trainLabels, testLabels) = self.preprocessData(file)
#     153
#     154         # create training and testing file
#
# ~/Documents/SONegativeCommentDetection/Models/FastText/FastText.py in preprocessData(self, file)
#      32         # load training and testing data
#      33         # with open('labeled_document2.json') as json_data:
# ---> 34         with open(file) as json_data:
#      35             allTrainData = json.load(json_data)
#      36
#
# FileNotFoundError: [Errno 2] No such file or directory: '../labeled_document_seconditer.json'

# %%
# total_result = {}
# epochs = [1]
# lr = [0.1]
# word_ngrams = [1]
# loss = ['ns', 'hs', 'softmax']
# dim = [100]
# ws = [1]

file = '../Models/LSTM/labeled_document_seconditer.json'
train_file = 'training_seconditer.txt'
test_file = 'testing_seconditer.txt'
model = FastText()
(postProcessedTrainPhrases, postProcessedTestPhrases, trainLabels, testLabels) = model.preprocessData(file)
testSentences = model.extractText(postProcessedTestPhrases)
# Out:
# init
# Loading and preprocessing data...

# %%
count = 1
total_result = {}
epochs = [5]
lr = [0.03, 0.05, 0.08, 0.1]
word_ngrams = [1, 2, 3]
loss = ['ns', 'hs', 'softmax']
dim = [100, 200, 300]
ws = [1, 5, 10]

with open("ft_parameters_temp.json", mode='w', encoding='utf-8') as f:
    for epoch_choice in epochs:
        for lr_choice in lr:
            for ngrams_choice in word_ngrams:
                for loss_choice in loss:
                    for dim_choice in dim:
                        for ws_choice in ws:
                            model_name = "ft_model_temp"
                            classifier = create_classifier(train_file, model_name, epoch_choice, lr_choice,
                                                           ngrams_choice, loss_choice, dim_choice, ws_choice)
                            res = classifier.predict(testSentences)
                            predicted = []
                            for i in res:
                                predicted.append(int(i[0]))
                            # print(predicted)
                            total_result[count] = {}
                            tn, fp, fn, tp = confusion_matrix(testLabels, predicted).ravel()
                            # print(tn, fp, fn, tp)
                            total_result[count]['confusion_matrix'] = []
                            total_result[count]['confusion_matrix'].append(int(tn))
                            total_result[count]['confusion_matrix'].append(int(fp))
                            total_result[count]['confusion_matrix'].append(int(fn))
                            total_result[count]['confusion_matrix'].append(int(tp))
                            # print(total_result[count]['confusion_matrix'])
                            report = precision_recall_fscore_support(testLabels, predicted)
                            total_result[count]['precision'] = report[0][0]
                            total_result[count]['recall'] = report[1][0]
                            total_result[count]['fbeta_score'] = report[2][0]
                            # print(report)
                            # print(report.fbeta_score)
                            total_result[count]['accuracy'] = classifier.test(test_file).precision
                            total_result[count]["ep"] = epoch_choice
                            total_result[count]["lr"] = lr_choice
                            total_result[count]["ngrams"] = ngrams_choice
                            total_result[count]["loss"] = loss_choice
                            total_result[count]["dim"] = dim_choice
                            total_result[count]["ws"] = ws_choice
                            # total_result[count]['model'] = [epoch_choice, lr_choice,ngrams_choice,loss_choice, dim_choice,ws_choice]
                            f = open("ft_parameters_temp.json", 'w')
                            f.write(json.dumps(total_result, indent=4, sort_keys=True))
                            f.close()
                            count += 1

f = open("ft_parameters_all.json", 'w+')
f.write(json.dumps(total_result, indent=4, sort_keys=True))
f.close()

# %%
class Individual():
    def __init__(self, epoch=1, lr=0, word_ngrams = 3, loss='ns', dim=300, ws=5,
                 precision=0, recall=0, fbeta=0, accuracy=0, confusion_matrix=None):
        self.epoch = epoch
        self.lr = lr
        self.word_ngrams = word_ngrams
        self.loss = loss
        self.dim = dim
        self.ws = ws
        self.precision = precision
        self.recall = recall
        self.fbeta = fbeta
        self.accuracy = accuracy
        self.confusion_matrix = confusion_matrix

    def sort_individuals(self, individuals, param):
        k = lambda x: int(x['1'][param])
        individuals = sorted(individuals, key=k, reverse=True)
        return individuals

# %%
def plot_eval(inds, filename):
    total_result = {}
    count = 1
    ep = 0
    lr = 0
    ngrams = 0
    loss = {'ns':0, 'hs':0, 'softmax':0}
    dim = 0
    ws = 0
    for i in inds:
        if i.precision > 0.5 and i.recall > 0.3:
            total_result[count] = {}
            total_result[count]['confusion_matrix'] = i.confusion_matrix
            total_result[count]['0precision'] = i.precision
            total_result[count]['recall'] = i.recall
            total_result[count]['fbeta_score'] = i.fbeta
            total_result[count]['accuracy'] = i.accuracy
            total_result[count]["ep"] = i.epoch
            total_result[count]["lr"] = i.lr
            total_result[count]["ngrams"] = i.word_ngrams
            total_result[count]["loss"] = i.loss
            total_result[count]["dim"] = i.dim
            total_result[count]["ws"] = i.ws
            ep += i.epoch
            lr += i.lr
            ngrams += i.word_ngrams
            loss[i.loss] = loss[i.loss]+1
            dim += i.dim
            ws += i.ws
            count += 1

    f = open("parameters_all_sorted_tn.json", 'w+')
    f.write(json.dumps(total_result, indent=4, sort_keys=True))
    f.close()
#     print(ep/count)
#     print(lr/count)
#     print(ngrams/count)
#     print(loss)
#     print(dim/count)
#     print(ws/count)

    color = sns.color_palette("hls", 8)
    y1 = []
    y2 = []
    y3 = []
    y4 = []
    x = []
    for i in range(1, count):
        x.append(i)
    for i in x:
        y1.append(total_result[i]['0precision'])
        y2.append(total_result[i]['recall'])
        y3.append(total_result[i]['fbeta_score'])
        # y4.append(total_result[i]['accuracy'])

    plt.figure(figsize=(20,12))
#     print(x)
#     print(len(x))
#     print(y1)
#     print(len(y1))
    ax = sns.pointplot(x, y1, alpha=0.8, color=color[1])
    ax = sns.pointplot(x, y2, alpha=0.8, color=color[2])
    ax = sns.pointplot(x, y3, alpha=0.8, color=color[3])
    # sns.pointplot(x, y4, alpha=0.8, color=color[4])
    # leg_handles = ax.get_legend_handles_labels()[0]
    # ax.legend(leg_handles, ['precision', 'recall', 'f_score'], title='legend')

    plt.ylabel('Evaluation', fontsize=12)
    plt.xlabel('Parameters Combination Id', fontsize=12)
    title = "FastText Performance Evaluation (" + filename + ")"
    plt.title(title, fontsize=15)
    plt.xticks(rotation='vertical')
    # plt.legend(['precision', 'recall', 'f_score'])
    plt.show()
    return total_result

# %%
with open("ft_parameters_all.json") as jsondata:
    data = json.load(jsondata)

# data = json.loads(open("ft_parameters_all.json").read())
    inds = []
    for v in data.values():
        ind = Individual(v['ep'], v['lr'], v['ngrams'], v['loss'], v['dim'], v['ws'], v['precision'],
                         v['recall'], v['fbeta_score'], v['accuracy'], v['confusion_matrix'])
        inds.append(ind)
    print(len(inds))
    print(len(data.values()))
    # inds = sorted(inds, key=lambda x: x.confusion_matrix[0], reverse=True)
    pop = sorted(inds, key=lambda x: x.fbeta, reverse=True)
    filename = "fbeta_score sorted"
    total_result = plot_eval(pop, filename)
# Out:
# 324
# 324

# %%
y= []
with open("ft_parameters_all.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y.append((count, data[d]['fbeta_score']))
        count+=1
color = sns.color_palette()

# %%
sort = sorted(y, key=lambda x: x[1],reverse=True)

datatable1 = []
datatable1.append(["Learning rate","Word ngrams","Loss","Word vector size","Window size", "Fbeta score", "Precision","Recall","Confusion Matrix", "Accuracy"])
sort_id = []
for i in sort:
    sort_id.append(i[0])
with open("ft_parameters_all.json") as jsondata:
    data = json.load(jsondata)
    for i in sort_id:
        datatable1.append([data[str(i)]['lr'],data[str(i)]['ngrams'],data[str(i)]['loss'],data[str(i)]['dim'],data[str(i)]['ws'],data[str(i)]['fbeta_score'],
                           data[str(i)]['precision'],data[str(i)]['recall'],data[str(i)]['confusion_matrix'], data[str(i)]['accuracy']] )
display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Learning rate</td><td>Word ngrams</td><td>Loss   </td><td>Word vector size</td><td>Window size</td><td>Fbeta score         </td><td>Precision          </td><td>Recall              </td><td>Confusion Matrix   </td><td>Accuracy          </td></tr>
# <tr><td>0.1          </td><td>1          </td><td>hs     </td><td>100             </td><td>5          </td><td>0.40119760479041916 </td><td>0.5583333333333333 </td><td>0.3130841121495327  </td><td>[67, 147, 53, 1130]</td><td>0.8568360773085183</td></tr>
# <tr><td>0.08         </td><td>2          </td><td>ns     </td><td>100             </td><td>1          </td><td>0.36196319018404904 </td><td>0.5267857142857143 </td><td>0.2757009345794392  </td><td>[59, 155, 53, 1130]</td><td>0.851109520400859 </td></tr>
# <tr><td>0.05         </td><td>1          </td><td>ns     </td><td>200             </td><td>10         </td><td>0.3602484472049689  </td><td>0.5370370370370371 </td><td>0.27102803738317754 </td><td>[58, 156, 50, 1133]</td><td>0.8525411596277738</td></tr>
# <tr><td>0.1          </td><td>3          </td><td>ns     </td><td>100             </td><td>5          </td><td>0.360128617363344   </td><td>0.5773195876288659 </td><td>0.2616822429906542  </td><td>[56, 158, 41, 1142]</td><td>0.8575518969219756</td></tr>
# <tr><td>0.08         </td><td>2          </td><td>ns     </td><td>200             </td><td>10         </td><td>0.3591331269349845  </td><td>0.5321100917431193 </td><td>0.27102803738317754 </td><td>[58, 156, 51, 1132]</td><td>0.8518253400143164</td></tr>
# <tr><td>0.1          </td><td>1          </td><td>hs     </td><td>200             </td><td>1          </td><td>0.3591331269349845  </td><td>0.5321100917431193 </td><td>0.27102803738317754 </td><td>[58, 156, 51, 1132]</td><td>0.8518253400143164</td></tr>
# <tr><td>0.1          </td><td>1          </td><td>hs     </td><td>200             </td><td>5          </td><td

# %%
top100 = sorted(y, key=lambda x: x[1],reverse=True)[0:100]
dataplot1= {'precision':[],'recall':[],'f1-score':[]}
top100_id = []
for i in top100:
    top100_id.append(i[0])
with open("ft_parameters_all.json") as jsondata:
    data = json.load(jsondata)
    for i in top100_id:
#         print(data[str(i)])
        dataplot1['precision'].append(data[str(i)]['precision'])
        dataplot1['recall'].append(data[str(i)]['recall'])
        dataplot1['f1-score'].append(data[str(i)]['fbeta_score'])
        
# display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
x = list(range(100))
# print(x)
# df = pd.DataFrame(data=dataplot1)
# print(len(dataplot1['precision']))
plt.figure(figsize=(20,12))
sns.pointplot(x, dataplot1['precision'], alpha=0.1, color=color[1])
sns.pointplot(x, dataplot1['recall'], alpha=0.2, color=color[2])
sns.pointplot(x, dataplot1['f1-score'], alpha=0.3, color=color[3])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[1], label="precision")
color_patch2 = mpatches.Patch(color=color[2], label="recall")
color_patch3 = mpatches.Patch(color=color[3], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("FastText (f1-score top 100)", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
y1 = []
y2 = []
y3 = []
y4 = []
with open("ft_parameters_all.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        if data[d]['fbeta_score']>0:
            y1.append(data[d]['precision'])
            y2.append(data[d]['recall'])
            y3.append(data[d]['fbeta_score'])
            y4.append(data[d]['accuracy'])
        
color = sns.color_palette()
x = list(range(len(y1)))
# print(x)
plt.figure(figsize=(20,12))
sns.pointplot(x, y1, alpha=0.1, color=color[1])
sns.pointplot(x, y2, alpha=0.2, color=color[2])
sns.pointplot(x, y3, alpha=0.3, color=color[3])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[1], label="precision")
color_patch2 = mpatches.Patch(color=color[2], label="recall")
color_patch3 = mpatches.Patch(color=color[3], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("FastText (all data)", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
file = '../Models/LSTM/labeled_document_seconditer.json'
isDS = False
model.classify(file,isDS)
# Out:
# Loading and preprocessing data...
#
# Buidling the model...
#
# Negative comments found:
#  whi ask question twice this one http //stackoverflow.com/questions/10688044/filling-a-array-with-uniqe-random-numbers-between-0-9-in-c-sharp
#  -1 lazi code dump
#  have look http //php.net/manual/en/language.oop5.visibility.php http //php.net/manual/en/language.oop5.visibility.php
#  what sort talk
#  hi-angel have look oper preceed http //en.cppreference.com/w/cpp/language/operator_preced you wrong preceed given miss whitespac around assign oper also read logic boolean oper evalu http //port70.net/~nsz/c/c11/n1570.html 6.5.13p4 basic c c++ onc one _inclusive-or-expression_ fail rest evalu anymor so `0` fail rest even evalu anymor
#  stack overflow question answer site profession enthusiast programm tutori base portal you obvious take help googl know magento
#  question clean work code ask code review https //codereview.stackexchange.com/
#  yet said _did_ debug found answer contradict detect
#  this question probabl `` homework '' tag
#  what inform find research access class multipl solut how inform found fail resolv problem
#  this sound like excel opportun learn
#  pointer arithmet http //stackoverflow.com/a/394774/620908 googl search https //www.google.com/search q=c 2b 2b+pointer+arithmet
#  love idea not work repli answer n't post one
#  off-top realli question
#  is homework
#  have tri anyth show attempt
#  welcom stack overflow it expect least attempt code stack overflow code write servic i would suggest **addit research** http //meta.stackoverflow.com/questions/261592/how-much-research-effort-is-expected-of-stack-overflow-us either via googl search so make attempt still troubl come back **your code** explain tri
#  it realli long you would n't care read so shorten
#  tri googl first come back stackoverflow
#  first tri post tri peopl help this help start http //www.learn-android-easily.com/2013/06/using-textwatcher-in-android.html https //www.learn2crack.com/2014/02/android-textwatcher-example.html
#  vostanazatyan absolut compet offer ilia shakitko correct recommend first read document
#  i 'm vote close question off-top homework question show ve tri far
#  stack overflow driven develop
#  you learn basic java or search internet this ask answer mani time
#  i googl exact question found https //www.google.com/search q=round+number+in+php ie=utf-8 oe=utf-8
#  dmitritsoy *perfect* tdd answer
#  this n't even cs question look like math quick googl search show formula
#  question
#  federicoklezculloca you ca n't wizard anyth without skill find basic inform doc
#  homework revis sheet im test ...
#  fix format post stack overflow
#  -1 your premis wrong https //ideone.com/wuxlac
#  yeah realli `npe` context you ll find answer
#  this question appear off-top too-localis
#  if re start ask peopl code like stack overflow place need you find good book seri onlin tutori have look good resourc learn objc http //stackoverflow.com/q/1374660 the big nerd ranch book excel lot peopl like stanford io cours itun u good luck
#  the best person ask would person set assign
#  you answer
#  this question four year old accept answer your answer duplic accept answer
#  you make answer
#  joebarri kurzedmet comment uncal put enough effort question you research post and need show thing tri pleas check http //stackoverflow.com/questions/how-to-ask inform
#  check http //programmers.stackexchange.com/questions/141834/how-is-a-java-reference-different-from-a-c-point
#  not n't show research effort question n't clear enough
#  pleas ask qualiti question you easili get answer search engin
#  whi i garner minus question is peopl n't know answer want take asker
#  did search error
#  what tri https //www.google.com/search q=c 23+convert+into+to+str
#  could easili got answer simpl googl search check http //www.w3schools.com/sql/sql_top.asp
#  yeah n't ask non-program question stackoverflow
#  lutzhorn 's homework
#  pleas format code 's easier read read post https //stackoverflow.com/questions/5963269/how-to-make-a-great-r-reproducible-exampl
#  we alway glad help support new coder ***you need help first *** after **do research** https //meta.stackoverflow.com/q/261592/1011527 problem **post ve tried** **clear explan n't working** provid minim complet verifi exampl http //stackoverflow.com/help/mcv read how ask http //stackoverflow.com/help/how-to-ask good question be sure take tour http //stackoverflow.com/tour read https //meta.stackoverflow.com/q/347937/1011527
#  anyth tri seem like want homework done
#  tri https //vim-adventures.com/ learn vim learn touch mous arrow key
#  hello just look profil all person ask question trivial googl they ve done hundr time they clear learn ask question so instead bother even simpl web search first ve reward peopl love upvot said question
#  possibl duplic my webpag wo n't let scroll https //stackoverflow.com/questions/9406693/my-webpage-wont-let-me-scrol
#  check demo http //jsfiddle.net/8e06dqz1/
#  pleas read ask take tour
#  pleas take tour http //stackoverflow.com/tour then read ask good question http //stackoverflow.com/help/how-to-ask
#  wow realli never thought
#  those error pretti self explanatori to elabor would take whole book https //stackoverflow.com/questions/388242/the-definitive-c-book-guide-and-list
#  smell like homework
#  so tri
#  *not* free code write servic you expect tri **write code yourself** after research http //meta.stackoverflow.com/questions/261592 problem **post ve tried** **clear explan n't working** provid ** mcve ** i suggest read ask good question perfect question http //codeblog.jonskeet.uk/2010/08/29/writing-the-perfect-question/ also sure take tour
#  you n't ask question
#  `smell like homework sound like op miss day class`
#  wrong answer pleas rectifi answer
#  did check http //api.jquery.com/jquery.ajax/
#  how tri far solv problem have check document
#  homework assign what tri solv
#  or could read inform introduct http //docs.python.org/3/tutorial/introduction.html string chapter kick tutori cover slice half-way page and presum sourc learn python short hack code n't understand ask random stranger explain thing n't seem work cover earli
#  newbiehask by look start c++ book tutori
#  even tri debug
#  i think search atleast post question basic i also suggest learn java documentation/book/anyth detail java work precis it may bit harsh tri thing 's learn
#  rtfm `defin name constant runtim http //php.net/defin
#  tri read https //msmvps.com/blogs/jon_skeet/archive/2010/08/29/writing-the-perfect-question.aspx
#  this link find servic googl exist exact purpos this site program question pleas spend time take tour read help page post next question
#  tri googl https //msdn.microsoft.com/en-us/library/ms228388.aspx
#  what thought
#  solut
#  yes tri read document
#  these basic concept cover first chapter zillion tutori 2-minut search dig
#  see componentimagecapture.java http //stackoverflow.com/questions/5853879/java-swing-obtain-image-of-jframe/5853992 5853992
#  read first comment care
#  you 126 previous question swift how claim ignor swift basic call method
#  have tri use `path.getdirectoryname` `fileinfo.directory` etc tri use googl ask so
#  t3chb0t good job googl friend
#  welcom stack overflow pleas take tour http //stackoverflow.com/tour what tri far pleas read how i ask good question http //stackoverflow.com/help/how-to-ask
#  did tri step code debugg
#  i 'm vote close question off-top question make sens
#  strong suggest read basic first
#  _every_ singl line question wrong you need learn lot write secur code
#  is question
#  woop you miss ask question pleas take tour learn ask come back proper mcve
#  did tri googl `` python gui ''
#  did search
#  https //developer.apple.com/documentation/swift/string/1690799-data
#  i 'm vote close question off-top author ought abl answer minimum read effort
#  use debugg
#  addit exact debug analys problem what result effort
#  if read error messag screen googl probabl could found answer
#  have heard googl msdn http //msdn.microsoft.com/en-us/library/527aztek.aspx
#  that code seem pointless it 's go yield strang result swift longer c-style `for construct ll build loop this smell like homework assign is
#  even aabl reproduc error check http //ideone.com/xrzyxu
#  question seek debug help `` n't code work '' must includ desir behavior specif problem error shortest code necessari reproduc question question without clear problem statement use reader see how creat minim complet verifi exampl https //stackoverflow.com/help/mcv
#  exact much research carri
#  search googl how python
#  proper way ask question
#  did even make attempt find solut come googl million hit
#  r.j got question answer
#  _what_ error also place `` guid error '' you need convers venu chat room discuss forum stack overflow q a like faq
#  sanchitbans have test code what test where perform bottleneck how determin bottleneck have look assembl languag these thing softwar engin would run straight stack overflow ask someon els provid answer futur macdonald employe would which want
#  that 's nice good luck figur did question
#  welcom so pleas read how creat minim complet verifi exampl http //stackoverflow.com/help/mcv also how i ask good question http //stackoverflow.com/help/how-to-ask
#  it expect least attempt code stack overflow code write servic i would suggest **addit research** http //meta.stackoverflow.com/questions/261592/how-much-research-effort-is-expected-of-stack-overflow-us either via googl search so make attempt still troubl come back **your code** explain tri
#  you basic sql tutori help lot ask
#  nisa this time someon edit question next time tri concis ellabor better question
#  so mani error ... java case-sensit pay attent cap
#  answer n't work
#  this question needless vagu miss context also like someon 's homework assign
#  yeah surpris mani peopl want homework never ever found someth use googl it 's like alway given big state secret investig ...
#  did read error messag
#  read basic sql tutori look inner join chapter
#  -1 this answer wrong
#  aleyaali reason deselect answer
#  micha how know ll first `h4` document hide
#  you read api document unsur
#  this generic descript problem actual specif question pleas see http //blog.stackoverflow.com/2010/10/asking-better-questions/ tri googl ask product question *love* answer
#  i recommend read mdn document `this` https //developer.mozilla.org/en-us/docs/web/javascript/reference/operators/thi
#  matt—perhap *i* flag
#
# Evaluating the model...
# Accuracy at 1:  0.04509663564781675
# Precision at 1: 0.8446671438797423
# Recall at 1: 0.8446671438797423
# Total number of examples: 1397
# Number of correctly predicted examples: 63
#
# Classifying sample texts...
# ['homework google', 'try it yourself', 'you didnt show any effort']
# [['0'], ['1'], ['0']]
