# %%
import matplotlib.pyplot as plt
import seaborn as sns
import json
import numpy as np
import matplotlib.patches as mpatches
from IPython.display import HTML, display
import tabulate
import pandas as pd

# %%
y= []
parameters = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y.append((count, data[d]['fbeta_score']))
        count+=1
        
color = sns.color_palette()

# %%
top30 = sorted(y, key=lambda x: x[1],reverse=True)[0:10]

datatable1 = []
datatable1.append(["Epochs","Actvation","Batchsize","Dropout","Optimizer","fbeta_score", "precision","recall","confusion_matrix", "Accuracy"])
top30_id = []
for i in top30:
    top30_id.append(i[0])
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for i in top30_id:
#         print(data[str(i)])
        datatable1.append([data[str(i)]['ep'],data[str(i)]['act'],data[str(i)]['batch'],data[str(i)]['drop'],data[str(i)]['op'], data[str(i)]['fbeta_score'],data[str(i)]['precision'],data[str(i)]['recall'],data[str(i)]['confusion_matrix'], data[str(i)]['accuracy']] )
#         datatable[0].append(data[str(i)]['act'])
#         datatable[1].append(data[str(i)]['batch'])
#         datatable[2].append(data[str(i)]['drop'])
#         datatable[3].append(data[str(i)]['op'])

display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Epochs</td><td>Actvation   </td><td>Batchsize</td><td>Dropout</td><td>Optimizer</td><td>fbeta_score       </td><td>precision         </td><td>recall            </td><td>confusion_matrix     </td><td>Accuracy         </td></tr>
# <tr><td>100   </td><td>sigmoid     </td><td>256      </td><td>0.5    </td><td>Adamax   </td><td>0.5943661971830985</td><td>0.5780821917808219</td><td>0.6115942028985507</td><td>[211, 134, 154, 1747]</td><td>87.17720391276896</td></tr>
# <tr><td>100   </td><td>sigmoid     </td><td>256      </td><td>0.5    </td><td>RMSprop  </td><td>0.5940860215053764</td><td>0.5538847117794486</td><td>0.6405797101449275</td><td>[221, 124, 178, 1723]</td><td>86.55387354767545</td></tr>
# <tr><td>100   </td><td>hard_sigmoid</td><td>256      </td><td>0.0    </td><td>Adam     </td><td>0.5863570391872278</td><td>0.5872093023255814</td><td>0.5855072463768116</td><td>[202, 143, 142, 1759]</td><td>87.26625111308994</td></tr>
# ...

# %%
top100 = sorted(y, key=lambda x: x[1],reverse=True)[0:180]

dataplot1= {'precision':[],'recall':[],'f1-score':[]}

top100_id = []
for i in top100:
    top100_id.append(i[0])
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for i in top100_id:
#         print(data[str(i)])
        dataplot1['precision'].append(data[str(i)]['precision'])
        dataplot1['recall'].append(data[str(i)]['recall'])
        dataplot1['f1-score'].append(data[str(i)]['fbeta_score'])
# display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
x = list(range(len(top100)))
# print(x)
# df = pd.DataFrame(data=dataplot1)
# print(len(dataplot1['precision']))
plt.figure(figsize=(20,12))
sns.pointplot(x, dataplot1['precision'], alpha=0.1, color=color[9])
sns.pointplot(x, dataplot1['recall'], alpha=0.2, color=color[7])
sns.pointplot(x, dataplot1['f1-score'], alpha=0.3, color=color[3])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[9], label="precision")
color_patch2 = mpatches.Patch(color=color[7], label="recall")
color_patch3 = mpatches.Patch(color=color[3], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Single Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
y2= []
parameters = []
with open("parameters_temp_stack2.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y2.append((count, data[d]['fbeta_score']))
        count+=1

        
top30 = sorted(y2, key=lambda x: x[1],reverse=True)[0:20]

datatable = []
datatable.append(["Actvation","Batchsize","Dropout","Optimizer","fbeta_score", "precision","recall","confusion_matrix", "Accuracy"])
top30_id = []
for i in top30:
    top30_id.append(i[0])
with open("parameters_temp_stack2.json") as jsondata:
    data = json.load(jsondata)
    for i in top30_id:
#         print(data[str(i)])
        datatable.append([data[str(i)]['act'],data[str(i)]['batch'],data[str(i)]['drop'],data[str(i)]['op'], data[str(i)]['fbeta_score'],data[str(i)]['precision'],data[str(i)]['recall'],data[str(i)]['confusion_matrix'], data[str(i)]['accuracy']] )
#         datatable[0].append(data[str(i)]['act'])
#         datatable[1].append(data[str(i)]['batch'])
#         datatable[2].append(data[str(i)]['drop'])
#         datatable[3].append(data[str(i)]['op'])

display(HTML(tabulate.tabulate(datatable, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Actvation   </td><td>Batchsize</td><td>Dropout</td><td>Optimizer</td><td>fbeta_score       </td><td>precision         </td><td>recall             </td><td>confusion_matrix     </td><td>Accuracy         </td></tr>
# <tr><td>sigmoid     </td><td>256      </td><td>0.1    </td><td>Adam     </td><td>0.598159509202454 </td><td>0.6351791530944625</td><td>0.5652173913043478 </td><td>[195, 150, 112, 1789]</td><td>88.3348174479426 </td></tr>
# <tr><td>softmax     </td><td>256      </td><td>0.5    </td><td>Adam     </td><td>0.5954198473282443</td><td>0.6290322580645161</td><td>0.5652173913043478 </td><td>[195, 150, 115, 1786]</td><td>88.20124665542257</td></tr>
# <tr><td>sigmoid     </td><td>256      </td><td>0.5    </td><td>Adam     </td><td>0.5846645367412141</td><td>0.6512455516014235</td><td>0.5304347826086957 </td><td>[183, 162, 98, 1803] </td><td>88.42386464295595</td></tr>
# ...

# %%
y3= []
parameters = []
with open("parameters_temp_stack3.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y3.append((count, data[d]['fbeta_score']))
        count+=1

        
top30 = sorted(y3, key=lambda x: x[1],reverse=True)[0:20]

datatable = []
datatable.append(["Actvation","Batchsize","Dropout","Optimizer","fbeta_score", "precision","recall","confusion_matrix", "Accuracy"])
top30_id = []
for i in top30:
    top30_id.append(i[0])
with open("parameters_temp_stack3.json") as jsondata:
    data = json.load(jsondata)
    for i in top30_id:
#         print(data[str(i)])
        datatable.append([data[str(i)]['act'],data[str(i)]['batch'],data[str(i)]['drop'],data[str(i)]['op'], data[str(i)]['fbeta_score'],data[str(i)]['precision'],data[str(i)]['recall'],data[str(i)]['confusion_matrix'], data[str(i)]['accuracy']] )
#         datatable[0].append(data[str(i)]['act'])
#         datatable[1].append(data[str(i)]['batch'])
#         datatable[2].append(data[str(i)]['drop'])
#         datatable[3].append(data[str(i)]['op'])

display(HTML(tabulate.tabulate(datatable, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Actvation   </td><td>Batchsize</td><td>Dropout</td><td>Optimizer</td><td>fbeta_score       </td><td>precision          </td><td>recall            </td><td>confusion_matrix     </td><td>Accuracy         </td></tr>
# <tr><td>sigmoid     </td><td>256      </td><td>0.1    </td><td>Adam     </td><td>0.588548601864181 </td><td>0.5443349753694581 </td><td>0.6405797101449275</td><td>[221, 124, 185, 1716]</td><td>86.24220837043633</td></tr>
# <tr><td>softmax     </td><td>256      </td><td>0.5    </td><td>Adam     </td><td>0.584518167456556 </td><td>0.6423611111111112 </td><td>0.5362318840579711</td><td>[185, 160, 103, 1798]</td><td>88.29029385043592</td></tr>
# <tr><td>softmax     </td><td>256      </td><td>0.1    </td><td>Adam     </td><td>0.5829596412556053</td><td>0.6018518518518519 </td><td>0.5652173913043478</td><td>[195, 150, 129, 1772]</td><td>87.57791629032906</td></tr>
# ...

# %%
y1 = []
y2 = []
y3 = []
y4 = []
parameters = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        if data[d]['fbeta_score']>0:
            y1.append(data[d]['precision'])
            y2.append(data[d]['recall'])
            y3.append(data[d]['fbeta_score'])
            y4.append(data[d]['accuracy'])
        
color = sns.color_palette()

# %%
hid1 = []
hid2 = []
batch1 = []
batch2 = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        if data[d]['fbeta_score']>0:
            if data[d]['hid'] == 128 :
                hid1.append(data[d]['fbeta_score'])
            else:
                hid2.append(data[d]['fbeta_score'])
    #         y1.append(data[d]['precision'])
    #         y2.append(data[d]['recall'])
            if data[d]['batch'] == 256 :
                batch1.append(data[d]['fbeta_score'])
            else:
                batch2.append(data[d]['fbeta_score'])
#         y4.append(data[d]['accuracy'])

# %%
print(color[3])
# Out:
# (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)

# %%
x = list(range(len(y1)))
# print(x)
plt.figure(figsize=(20,12))
sns.pointplot(x, y1, alpha=0.1, color=color[1])
sns.pointplot(x, y2, alpha=0.2, color=color[2])
sns.pointplot(x, y3, alpha=0.3, color=color[3])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[1], label="precision")
color_patch2 = mpatches.Patch(color=color[2], label="recall")
color_patch3 = mpatches.Patch(color=color[3], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Single Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# plt.savefig("LSTM1.png")

# %%
x1 = list(range(len(hid1)))
x2 = list(range(len(hid2)))
# print(x)
plt.figure(figsize=(20,12))
sns.pointplot(x1, hid1, alpha=0.1, color=color[5])
sns.pointplot(x2, hid2, alpha=0.2, color=color[7])

# sns.pointplot(x, y4, alpha=0.4, color=color[6])
color_patch1 = mpatches.Patch(color=color[5], label="Hiddensize1")
color_patch2 = mpatches.Patch(color=color[7], label="Hiddensize2")
plt.legend(handles=[color_patch1,color_patch2])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Hiddensize 128 vs 256", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
x1 = list(range(len(batch1)))
x2 = list(range(len(batch2)))
# print(x)
plt.figure(figsize=(20,12))

sns.pointplot(x1, batch1, alpha=0.1, color=color[1])
sns.pointplot(x2, batch2, alpha=0.2, color=color[4])

# sns.pointplot(x, y4, alpha=0.4, color=color[6])

plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Batchsize tuning", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
drop1 = []
drop2 = []
drop3 = []
drop4 = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        if data[d]['fbeta_score']>0:
            if data[d]['drop'] == 0.0:
                drop1.append(data[d]['fbeta_score'])
            elif data[d]['drop'] == 0.1:
                drop2.append(data[d]['fbeta_score'])
            elif data[d]['drop'] == 0.25:
                drop3.append(data[d]['fbeta_score'])
            elif data[d]['drop'] == 0.5:
                drop4.append(data[d]['fbeta_score'])

# %%
x1 = list(range(len(drop1)))
x2 = list(range(len(drop2)))
x3 = list(range(len(drop3)))
x4 = list(range(len(drop4)))

# print(x)
plt.figure(figsize=(20,12))

sns.pointplot(x1, drop1, alpha=0.1, color=color[5])
sns.pointplot(x2, drop2, alpha=0.1, color=color[7])
sns.pointplot(x3, drop3, alpha=0.1, color=color[4])
sns.pointplot(x4, drop4, alpha=0.1, color=color[3])

color_patch1 = mpatches.Patch(color=color[5], label="precision")
color_patch2 = mpatches.Patch(color=color[7], label="recall")
color_patch3 = mpatches.Patch(color=color[4], label="fbeta_score")
color_patch4 = mpatches.Patch(color=color[3], label="fbeta_score2")
plt.legend(handles=[color_patch1,color_patch2,color_patch3, color_patch4])
# handles = [color_patch1,color_patch2, color_patch3,color_patch4]
# print(handles)

plt.legend( handles = [color_patch1,color_patch2, color_patch3,color_patch4])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("DropoutRate", fontsize=15)
plt.xticks(rotation='vertical')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
y2= []
parameters = []
with open("parameters_temp_stack2.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y2.append((count, data[d]['fbeta_score']))
        count+=1

        
top100 = sorted(y2, key=lambda x: x[1],reverse=True)[0:20]
print(top100)

dataplot2= {'precision':[],'recall':[],'f1-score':[]}

top100_id = []
for i in top100:
    top100_id.append(i[0])
with open("parameters_temp_stack2.json") as jsondata:
    data = json.load(jsondata)
    for i in top100_id:
#         print(data[str(i)])
        dataplot2['precision'].append(data[str(i)]['precision'])
        dataplot2['recall'].append(data[str(i)]['recall'])
        dataplot2['f1-score'].append(data[str(i)]['fbeta_score'])
# display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
x = list(range(len(top100)))
# print(x)
# df = pd.DataFrame(data=dataplot1)
# print(len(dataplot1['precision']))
plt.figure(figsize=(20,12))
print(dataplot2['precision'])
sns.pointplot(x, dataplot2['precision'], alpha=0.1, color=color[4])
sns.pointplot(x, dataplot2['recall'], alpha=0.2, color=color[5])
sns.pointplot(x, dataplot2['f1-score'], alpha=0.3, color=color[6])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[4], label="precision")
color_patch2 = mpatches.Patch(color=color[5], label="recall")
color_patch3 = mpatches.Patch(color=color[6], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Double Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# [(3, 0.598159509202454), (18, 0.5954198473282443), (6, 0.5846645367412141), (21, 0.5831062670299727), (36, 0.5783132530120482), (30, 0.5781710914454277), (24, 0.5757162346521145), (33, 0.5753424657534246), (32, 0.5698924731182796), (23, 0.5695708712613784), (2, 0.5676855895196505), (26, 0.5676855895196505), (35, 0.5654596100278552), (20, 0.5595716198125836), (27, 0.559322033898305), (15, 0.545736434108527), (17, 0.5368098159509203), (9, 0.5335515548281506), (14, 0.5322834645669292), (5, 0.4739884393063584)]
# [0.6351791530944625, 0.6290322580645161, 0.6512455516014235, 0.5501285347043702, 0.5373134328358209, 0.5885885885885885, 0.5438144329896907, 0.5454545454545454, 0.531328320802005, 0.5165094339622641, 0.5701754385964912, 0.5701754385964912, 0.5442359249329759, 0.5199004975124378, 0.5454545454545454, 0.5866666666666667, 0.5700325732899023, 0.6127819548872181, 0.5827586206896552, 0.7068965517241379]

# %%
y3= []
parameters = []
with open("parameters_temp_stack3.json") as jsondata:
    data = json.load(jsondata)
    count = 1
    for d in data:
        y3.append((count, data[d]['fbeta_score']))
        count+=1

        
top100 = sorted(y3, key=lambda x: x[1],reverse=True)[0:20]
print(top100)

dataplot3= {'precision':[],'recall':[],'f1-score':[]}

top100_id = []
for i in top100:
    top100_id.append(i[0])
with open("parameters_temp_stack3.json") as jsondata:
    data = json.load(jsondata)
    for i in top100_id:
#         print(data[str(i)])
        dataplot3['precision'].append(data[str(i)]['precision'])
        dataplot3['recall'].append(data[str(i)]['recall'])
        dataplot3['f1-score'].append(data[str(i)]['fbeta_score'])
# display(HTML(tabulate.tabulate(datatable1, tablefmt='html')))
x = list(range(len(top100)))
# print(x)
# df = pd.DataFrame(data=dataplot1)
# print(len(dataplot1['precision']))
plt.figure(figsize=(20,12))
print(dataplot2['precision'])
sns.pointplot(x, dataplot3['precision'], alpha=0.1, color=color[4])
sns.pointplot(x, dataplot3['recall'], alpha=0.2, color=color[5])
sns.pointplot(x, dataplot3['f1-score'], alpha=0.3, color=color[6])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

color_patch1 = mpatches.Patch(color=color[4], label="precision")
color_patch2 = mpatches.Patch(color=color[5], label="recall")
color_patch3 = mpatches.Patch(color=color[6], label="fbeta_score")
plt.legend(handles=[color_patch1,color_patch2,color_patch3])
plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Triple Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# [(21, 0.588548601864181), (18, 0.584518167456556), (15, 0.5829596412556053), (6, 0.5829457364341086), (36, 0.5794392523364487), (35, 0.5755584756898817), (29, 0.575197889182058), (3, 0.5739644970414202), (33, 0.5706806282722514), (24, 0.56986301369863), (9, 0.5698478561549102), (32, 0.5658914728682171), (23, 0.5624142661179699), (2, 0.5575364667747164), (30, 0.556473829201102), (20, 0.5542483660130719), (27, 0.5485564304461943), (12, 0.5476923076923078), (14, 0.5349182763744428), (17, 0.5123537061118336)]
# [0.6351791530944625, 0.6290322580645161, 0.6512455516014235, 0.5501285347043702, 0.5373134328358209, 0.5885885885885885, 0.5438144329896907, 0.5454545454545454, 0.531328320802005, 0.5165094339622641, 0.5701754385964912, 0.5701754385964912, 0.5442359249329759, 0.5199004975124378, 0.5454545454545454, 0.5866666666666667, 0.5700325732899023, 0.6127819548872181, 0.5827586206896552, 0.7068965517241379]
