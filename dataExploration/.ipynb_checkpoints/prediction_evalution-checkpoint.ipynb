# %%
import matplotlib.pyplot as plt
import seaborn as sns
import json
import numpy as np

# %%
y1 = []
y2 = []
y3 = []
y4 = []
parameters = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        y1.append(data[d]['precision'])
        y2.append(data[d]['recall'])
        y3.append(data[d]['fbeta_score'])
        y4.append(data[d]['accuracy'])
        
color = sns.color_palette()

# %%
hid1 = []
hid2 = []
batch1 = []
batch2 = []
with open("parameters_temp_1stack.json") as jsondata:
    data = json.load(jsondata)
    for d in data:
        if data[d]['hid'] == 128:
            hid1.append(data[d]['fbeta_score'])
        else:
            hid2.append(data[d]['fbeta_score'])
#         y1.append(data[d]['precision'])
#         y2.append(data[d]['recall'])
        if data[d]['batch'] == 256:
            batch1.append(data[d]['fbeta_score'])
        else:
            batch2.append(data[d]['fbeta_score'])
#         y4.append(data[d]['accuracy'])

# %%
print(color[3])
# Out:
# (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)

# %%
x = list(range(len(y1)))
# print(x)
plt.figure(figsize=(20,12))
sns.pointplot(x, y1, alpha=0.1, color=color[1])
sns.pointplot(x, y2, alpha=0.2, color=color[2])
sns.pointplot(x, y3, alpha=0.3, color=color[3])
# sns.pointplot(x, y4, alpha=0.4, color=color[6])

plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Single Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
# plt.savefig("LSTM1.png")

# %%
x = list(range(len(hid1)))
# print(x)
plt.figure(figsize=(20,12))
sns.pointplot(x, hid1, alpha=0.1, color=color[1])
sns.pointplot(x, hid2, alpha=0.2, color=color[2])

# sns.pointplot(x, y4, alpha=0.4, color=color[6])

plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Single Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
print(batch2)
# Out:
# [0.0, 0.0, 0.49719626168224296, 0.5540334855403349, 0.5674418604651164, 0.5742904841402338, 0.49063032367972736, 0.4797507788161994, 0.0, 0.0, 0.5027522935779817, 0.5089141004862237, 0.5586107091172214, 0.5658263305322129, 0.4921135646687697, 0.48946515397082657, 0.0, 0.0, 0.535031847133758, 0.4908424908424908, 0.566813509544787, 0.5537974683544303, 0.48319999999999996, 0.46127366609294324, 0.0, 0.0, 0.47122302158273377, 0.5300813008130081, 0.5342237061769616, 0.5381944444444444, 0.4970059880239521, 0.4739336492890995, 0.0, 0.0, 0.3924843423799582, 0.0, 0.5275459098497497, 0.07756232686980608, 0.3678646934460888, 0.4553734061930783, 0.0, 0.0, 0.022922636103151862, 0.4935543278084715, 0.5275590551181102, 0.5202797202797202, 0.2857142857142857, 0.060941828254847646, 0.0, 0.0, 0.3466666666666667, 0.3249427917620137, 0.5046153846153846, 0.5116918844566712, 0.13192612137203166, 0.022922636103151862, 0.0, 0.0, 0.0, 0.0, 0.37422037422037424, 0.5170068027210883, 0.005780346820809248, 0.26252
# ...

# %%
x1 = list(range(len(batch1)))
x2 = list(range(len(batch2)))
# print(x)
plt.figure(figsize=(20,12))

sns.pointplot(x1, batch1, alpha=0.1, color=color[1])
sns.pointplot(x2, batch2, alpha=0.2, color=color[4])

# sns.pointplot(x, y4, alpha=0.4, color=color[6])

plt.ylabel('Evaluation', fontsize=12)
plt.xlabel('Parameters combination', fontsize=12)
plt.title("Single Stack LSTM", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()
